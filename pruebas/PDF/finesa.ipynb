# %%
from pdfminer.high_level import extract_pages
for page_layout in extract_pages("finesa.pdf"):
    for element in page_layout:
        print(element)
# Out:
# Fecha Expedición:
#
# 13-10-2021
#
# ESTADO DE CUENTA
#
# INFORMACIÓN DEL CLIENTE
#
# Nombre Deudor:
#
# HEPTAGON GROUP SAS
#
# Número Identificación:
#
# 900,667,308
#
# Número de
# Préstamo
#
# Fecha de
# Desembolso
#
# Valor Original
#
# Plazo
# (Meses)
#
# Cuotas
# Facturadas
#
# Cuotas
# Pendientes
#
# Dia Límite Pago
# Cuotas
#
# 100129876
#
# 05-07-2016
#
# 48,740,000
#
# 60
#
# 51
#
# 9
#
# 28
#
# INFORMACIÓN DEL PAGO DEL 20170804
#
# Concepto
#
# Valor
#
# CUOTA DE RECAUDO
#
# ESTUDIO CREDITO
#
# IVA CUOTA DE RECAUDO
#
# INT CORR
#
# SEGURO VIDA ALLIANZ
#
# IVA ESTUDIO CREDITO
#
# REG GAR CONFECAMARAS
#
# IVA CUOTA DE RECAUDO
#
# CUOTA DE RECAUDO
#
# SEGURO VIDA ALLIANZ
#
# CAPITAL
#
# INT MORA
#
# INT CORR
#
# 2,500
#
# 19,000
#
# 400
#
# 1,393,755
#
# 1,004,744
#
# 3,040
#
# 38,280
#
# 2,461,719
#
# 627
#
# 3,300
#
# 643,142
#
# 77,288
#
# 8,416
#
# 703,535
#
# Total
#
# INFORMACIÓN DEL PAGO DEL 20170922
#
# Concepto
#
# Valor
#
# ...
